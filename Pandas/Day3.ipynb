# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/Users/danialmendigali/jupyter-datascience/Pandas/data set /Fortnite Statistics.csv')
df1 = pd.read_csv('/Users/danialmendigali/jupyter-datascience/Pandas/data set /Titanic-Dataset.csv')

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(5)
# Out:
#    Date Time of Day  Placed Mental State  Eliminations  Assists  Revives  \
# 0  4/10     6:00 PM      27        sober             2        0        0
# 1  4/10     6:00 PM      45        sober             1        2        0
# 2  4/10     6:00 PM      38         high             3        0        0
# 3  4/10     7:00 PM      30         high             1        3        0
# 4  4/10     7:00 PM      16         high             3        1        1
#
#   Accuracy  Hits  Head Shots  Distance Traveled  Materials Gathered  \
# 0      23%    14           2             271.08                  20
# 1      30%    19           1             396.73                 123
# 2      30%    32           1             607.80                  71
# 3      18%    19           1             714.16                 244
# 4      58%    42          18            1140.00                 584
#
#    Materials Used  Damage Taken  Damage to Players  Damage to Structures
# ...

# %% [markdown]
# # Добавление колонок

# %%
df['skin'] =  "Vladika lda"

# %%
df.head(5)
# Out:
#    Date Time of Day  Placed Mental State  Eliminations  Assists  Revives  \
# 0  4/10     6:00 PM      27        sober             2        0        0
# 1  4/10     6:00 PM      45        sober             1        2        0
# 2  4/10     6:00 PM      38         high             3        0        0
# 3  4/10     7:00 PM      30         high             1        3        0
# 4  4/10     7:00 PM      16         high             3        1        1
#
#   Accuracy  Hits  Head Shots  Distance Traveled  Materials Gathered  \
# 0      23%    14           2             271.08                  20
# 1      30%    19           1             396.73                 123
# 2      30%    32           1             607.80                  71
# 3      18%    19           1             714.16                 244
# 4      58%    42          18            1140.00                 584
#
#    Materials Used  Damage Taken  Damage to Players  Damage to Structures  \
# ...

# %%
df['skin'] = 'Unknown'
df.loc[df['Hits'] < 20, 'skin'] = 'Banana'
df.loc[df['Hits'].between(20, 25), 'skin'] = 'Vladika'
df.loc[df['Hits'] > 25, 'skin'] = 'SeniorPomidor'

# %%
df.tail(20)
# Out:
#       Date Time of Day  Placed Mental State  Eliminations  Assists  Revives  \
# 67    4/15     1:00 PM      17        sober             2        0        0
# 68    4/15     1:00 PM      13        sober             6        2        0
# 69    4/15     2:00 PM       5        sober             6        3        0
# 70    4/15     2:00 PM      41        sober             0        1        0
# 71    4/15     5:00 PM      25         high             2        2        1
# 72    4/15     5:00 PM      20         high             0        3        0
# 73    4/15     5:00 PM      15         high             2        2        1
# 74    4/15     6:00 PM       1         high             4        5        0
# 75    4/15     6:00 PM      22         high             3        3        1
# 76    4/15    10:00 PM      15        sober             3        0        1
# 77    4/15    11:00 PM      34        sober             2        2        1
# ...

# %%
df1['is_adult'] = np.where(df1['Age'] >= 18, 'Yes', 'No')
df1.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df1['is_male'] = np.where(df1['Sex'] == 'male', 1, 0)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1['age_group'] = np.where(
    df1['Age'] < 18, 'Child',
    np.where(df1['Age'] < 60, 'Adult', 'Senior')
)
df1.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked is_adult  \
# 886    male  27.0      0      0      211536  13.00   NaN        S      Yes
# 887  female  19.0      0      0      112053  30.00   B42        S      Yes
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S       No
# 889    male  26.0      0      0      111369  30.00  C148        C      Yes
# 890    male  32.0      0      0      370376   7.75   NaN        Q      Yes
#
#      is_male age_group
# 886        1     Adult
# ...

# %%
n = df1.loc[
    (df1['Age'] > 59)
]
n.head(5)
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 96            97         0       1       Goldschmidt, Mr. George B  male
# 116          117         0       3            Connors, Mr. Patrick  male
# 170          171         0       1       Van der hoef, Mr. Wyckoff  male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked is_adult  is_male  \
# 33   66.0      0      0  C.A. 24579  10.5000   NaN        S      Yes        1
# 54   65.0      0      1      113509  61.9792   B30        C      Yes        1
# 96   71.0      0      0    PC 17754  34.6542    A5        C      Yes        1
# 116  70.5      0      0      370369   7.7500   NaN        Q      Yes        1
# 170  61.0      0      0      111240  33.5000   B19        S      Yes        1
#
#     age_group
# 33     Senior
# 54     Senior
# ...

# %%
df1['age_group'] = np.where(
    df1['Age'] < 18, 'Child',
    np.where(df1['Age'] < 60, 'Adult', 'Senior')
)
d = df1.loc[
    (df1['Age'] > 60)
]
d.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2                Mitchell, Mr. Henry Michael
# 745          746         0       1               Crosby, Capt. Edward Gifford
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
# 851          852         0       3                        Svensson, Mr. Johan
#
#         Sex   Age  SibSp  Parch      Ticket    Fare Cabin Embarked age_group
# 630    male  80.0      0      0       27042  30.000   A23        S    Senior
# 672    male  70.0      0      0  C.A. 24580  10.500   NaN        S    Senior
# 745    male  70.0      1      1   WE/P 5735  71.000   B22        S    Senior
# 829  female  62.0      0      0      113572  80.000   B28      NaN    Senior
# 851    male  74.0      0      0      347060   7.775   NaN        S    Senior

# %%
df1['fare_group'] = np.where(
    df1['Fare'] < 20, 'low',
    np.where(df1['Fare'].between(20, 50), 'medium', 'high')
)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.groupby('age_group')['Age'].mean()
# Out:
# age_group
# Adult     32.158261
# Child      9.041327
# Senior    65.096154
# Name: Age, dtype: float64

# %%
df1.groupby('fare_group')['Fare'].mean()
# Out:
# fare_group
# high      108.303202
# low         9.727127
# medium     29.425772
# Name: Fare, dtype: float64

# %%
pr1 = df1.loc[
    (df1['Sex'] == 'male') & 
    (df1['Age'] > 30)
]
pr1
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 4              5         0       3              Allen, Mr. William Henry
# 6              7         0       1               McCarthy, Mr. Timothy J
# 13            14         0       3           Andersson, Mr. Anders Johan
# 20            21         0       2                  Fynney, Mr. Joseph J
# 21            22         1       2                 Beesley, Mr. Lawrence
# ..           ...       ...     ...                                   ...
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 873          874         0       3           Vander Cruyssen, Mr. Victor
# 881          882         0       3                    Markun, Mr. Johann
# 890          891         0       3                   Dooley, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked  \
# ...

# %%
pr2 = df1.loc[
    (df1['Sex'] == 'female') &
    (df1['Pclass'] == 1) &
    (df1['Fare'] > 50)
]
pr2
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 52            53         1       1
# 61            62         1       1
# ..           ...       ...     ...
# 835          836         1       1
# 849          850         1       1
# 856          857         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 61                                 Icard, Miss. Amelie  female  38.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pr3 = df1.loc[
    (df1['Name'].str.contains(r'Mrs\.|Miss\.', case=False))
]
pr3
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
pr4 = df1.loc[
    (df1['age_group'] == 'Child') &
    (df1['Survived'] == 1)
]
pr4
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 9             10         1       2       Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# 39            40         1       3               Nicola-Yarred, Miss. Jamila
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 830          831         1       3   Yasbeck, Mrs. Antoni (Selini Alexander)
# 831          832         1       2           Richards, Master. George Sibley
# 853          854         1       1                 Lines, Miss. Mary Conover
# 869          870         1       3           Johnson, Master. Harold Theodor
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
#
# ...

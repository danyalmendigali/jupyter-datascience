# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/Users/danialmendigali/jupyter-datascience/Pandas/data set /Titanic-Dataset.csv')

# %%
df[df['Name'].str.startswith('M')].tail(5)
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 839          840         1       1      Marechal, Mr. Pierre  male   NaN
# 841          842         0       2  Mudd, Mr. Thomas Charles  male  16.0
# 847          848         0       3        Markoff, Mr. Marin  male  35.0
# 881          882         0       3        Markun, Mr. Johann  male  33.0
# 886          887         0       2     Montvila, Rev. Juozas  male  27.0
#
#      SibSp  Parch       Ticket     Fare Cabin Embarked
# 839      0      0        11774  29.7000   C47        C
# 841      0      0  S.O./P.P. 3  10.5000   NaN        S
# 847      0      0       349213   7.8958   NaN        C
# 881      0      0       349257   7.8958   NaN        S
# 886      0      0       211536  13.0000   NaN        S

# %%
df[df['Name'].str.endswith('f')]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 48            49         0       3           Samaan, Mr. Youssef  male   NaN
# 130          131         0       3          Drazenoic, Mr. Jozef  male  33.0
# 170          171         0       1     Van der hoef, Mr. Wyckoff  male  61.0
# 232          233         0       2     Sjostedt, Mr. Ernst Adolf  male  59.0
# 342          343         0       2    Collander, Mr. Erik Gustaf  male  28.0
# 353          354         0       3     Arnold-Franchi, Mr. Josef  male  25.0
# 391          392         1       3        Jansson, Mr. Carl Olof  male  21.0
# 499          500         0       3            Svensson, Mr. Olof  male  24.0
# 636          637         0       3    Leinonen, Mr. Antti Gustaf  male  32.0
# 798          799         0       3  Ibrahim Shawah, Mr. Yousseff  male  30.0
# 840          841         0       3   Alhomaki, Mr. Ilmari Rudolf  male  20.0
# ...

# %%
df[df['Name'].str.contains('Mrs', regex=False)].head(5)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 8             9         1       3
# 9            10         1       2
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 8       2    347742  11.1333   NaN        S
# 9       0    237736  30.0708   NaN        C
# 15      0    248706  16.0000   NaN        S

# %%
## The separator is indicated in brackets - by what the string will be split.
df['LastName'] = df['Name'].str.split(',').str[0] ## Breaking text into parts

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Title'] = df['Name'].str.split(',').str[1].str.split('.').str[0].str.strip()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Name'].str.contains('Mrs')].head(5)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 8             9         1       3
# 9            10         1       2
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  LastName Title
# 1       0  PC 17599  71.2833   C85        C   Cumings   Mrs
# 3       0    113803  53.1000  C123        S  Futrelle   Mrs
# 8       2    347742  11.1333   NaN        S   Johnson   Mrs
# 9       0    237736  30.0708   NaN        C    Nasser   Mrs
# ...

# %%
df[df['Name'].str.startswith('A')]
# Out:
#      PassengerId  Survived  Pclass  \
# 4              5         0       3
# 13            14         0       3
# 25            26         1       3
# 40            41         0       3
# 49            50         0       3
# 68            69         1       3
# 91            92         0       3
# 114          115         0       3
# 119          120         0       3
# 144          145         0       2
# 146          147         1       3
# 182          183         0       3
# 192          193         1       3
# 207          208         1       3
# 210          211         0       3
# 233          234         1       3
# 244          245         0       3
# 261          262         1       3
# 275          276         1       1
# 279          280         1       3
# 297          298         0       1
# 305          306         1       1
# 308          309         0       2
# 353          354         0       3
# 363          364         0       3
# ...

# %%
df['Title'] = df['Name'].str.split(',').str[1].str.split('.').str[0].str.strip()

# %%
df['Surname'] = df['Name'].str.split(',').str[0]

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked Title Surname
# 889      0  111369  30.00  C148        C    Mr    Behr
# 890      0  370376   7.75   NaN        Q    Mr  Dooley

# %%
df.loc[
    (df['Name'].str.split(',').str[0].str.len() > 7)
].head(5)
# Out:
#     PassengerId  Survived  Pclass  \
# 2             3         1       3
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 12           13         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 2                         Heikkinen, Miss. Laina  female  26.0      0      0
# 3   Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 6                        McCarthy, Mr. Timothy J    male  54.0      0      0
# 10               Sandstrom, Miss. Marguerite Rut  female   4.0      1      1
# 12                Saundercock, Mr. William Henry    male  20.0      0      0
#
#               Ticket     Fare Cabin Embarked Title      Surname
# 2   STON/O2. 3101282   7.9250   NaN        S  Miss    Heikkinen
# 3             113803  53.1000  C123        S   Mrs     Futrelle
# 6              17463  51.8625   E46        S    Mr     McCarthy
# ...

# %%
df1 = pd.read_csv('/Users/danialmendigali/jupyter-datascience/Pandas/data set /StudentsPerformance.csv')

# %%
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df1['gender'] = df1['gender'].str.upper()

# %%
df1.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  FEMALE        group B           bachelor's degree      standard
# 1  FEMALE        group C                some college      standard
# 2  FEMALE        group B             master's degree      standard
# 3    MALE        group A          associate's degree  free/reduced
# 4    MALE        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df1['gender'].value_counts()
# Out:
# gender
# FEMALE    518
# MALE      482
# Name: count, dtype: int64

# %%
df.loc[
    df['Name'].str.split(',').str[1].str.split('.').str[1].str.strip().str.startswith('A')
].head(5)
# Out:
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 13           14         0       3         Andersson, Mr. Anders Johan    male
# 22           23         1       3         McGowan, Miss. Anna "Annie"  female
# 35           36         0       1      Holverson, Mr. Alexander Oskar    male
# 38           39         0       3  Vander Planke, Miss. Augusta Maria  female
# 61           62         1       1                 Icard, Miss. Amelie  female
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 13  39.0      1      5  347082  31.2750   NaN        S
# 22  15.0      0      0  330923   8.0292   NaN        Q
# 35  42.0      1      0  113789  52.0000   NaN        S
# 38  18.0      2      0  345764  18.0000   NaN        S
# 61  38.0      0      0  113572  80.0000   B28      NaN

# %%
df['first_letter'] = df['Name'].str.split(',').str[1].str.split('.').str[1].str.split()

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked  \
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
#
#                      first_letter
# 886                      [Juozas]
# 887             [Margaret, Edith]
# ...

# %%
df.loc[
    (df['Name'].str.split(',').str[1].str.split('.').str[1].str.strip().str.startswith('A')) &
    (df['Age'] > 50),
    'Age'
].mean()
# Out:
# np.float64(61.9)

# %%
group_a = pd.DataFrame({
    'student_id': range(1, 11),
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Hannah', 'Ian', 'Jack'],
    'age': np.random.randint(18, 25, size=10),
    'math_score': np.random.randint(60, 100, size=10)
})

group_b = pd.DataFrame({
    'student_id': range(11, 21),
    'name': ['Kevin', 'Laura', 'Mike', 'Nina', 'Oscar', 'Paula', 'Quinn', 'Rachel', 'Steve', 'Tina'],
    'age': np.random.randint(18, 25, size=10),
    'math_score': np.random.randint(60, 100, size=10)
})

# %%
group_a
# Out:
#    student_id     name  age  math_score
# 0           1    Alice   20          63
# 1           2      Bob   23          67
# 2           3  Charlie   20          76
# 3           4    David   19          83
# 4           5      Eva   24          88
# 5           6    Frank   18          85
# 6           7    Grace   22          63
# 7           8   Hannah   21          92
# 8           9      Ian   24          98
# 9          10     Jack   19          94

# %%
group_b
# Out:
#    student_id    name  age  math_score
# 0          11   Kevin   22          61
# 1          12   Laura   18          83
# 2          13    Mike   22          90
# 3          14    Nina   24          64
# 4          15   Oscar   21          69
# 5          16   Paula   21          62
# 6          17   Quinn   23          86
# 7          18  Rachel   21          68
# 8          19   Steve   20          79
# 9          20    Tina   23          98

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/Users/danialmendigali/jupyter-datascience/Pandas/data set /insurance.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
df['type_bmi'] = np.where(
    df['bmi'].between(20, 30), 'low',
    np.where(df['bmi'].between(31, 40), 'middle', 'high')
)

# %%
df.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges type_bmi
# 0   19  female  27.900         0    yes  southwest  16884.92400      low
# 1   18    male  33.770         1     no  southeast   1725.55230   middle
# 2   28    male  33.000         3     no  southeast   4449.46200   middle
# 3   33    male  22.705         0     no  northwest  21984.47061      low
# 4   32    male  28.880         0     no  northwest   3866.85520      low

# %%
df['rank_bmi'] = df['bmi'].rank()

# %%
df.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges type_bmi  \
# 0   19  female  27.900         0    yes  southwest  16884.92400      low
# 1   18    male  33.770         1     no  southeast   1725.55230   middle
# 2   28    male  33.000         3     no  southeast   4449.46200   middle
# 3   33    male  22.705         0     no  northwest  21984.47061      low
# 4   32    male  28.880         0     no  northwest   3866.85520      low
#
#    rank_bmi
# 0     459.0
# 1     943.5
# 2     879.5
# 3     124.0
# 4     541.5

# %%
df['new_region'] = df['region'].apply(lambda x: x.upper())

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges type_bmi  \
# 1333   50    male  30.97         3     no  northwest  10600.5483     high
# 1334   18  female  31.92         0     no  northeast   2205.9808   middle
# 1335   18  female  36.85         0     no  southeast   1629.8335   middle
# 1336   21  female  25.80         0     no  southwest   2007.9450      low
# 1337   61  female  29.07         0    yes  northwest  29141.3603      low
#
#       rank_bmi new_region
# 1333     722.0  NORTHWEST
# 1334     796.0  NORTHEAST
# 1335    1124.0  SOUTHEAST
# 1336     302.0  SOUTHWEST
# 1337     562.5  NORTHWEST

# %%
gr1 = df.groupby(['sex', 'smoker']).agg({
    'bmi' : ['min', 'max']
})

# %%
gr1
# Out:
#                   bmi
#                   min    max
# sex    smoker
# female no      16.815  48.07
#        yes     17.195  47.60
# male   no      15.960  53.13
#        yes     17.290  52.58

# %%
df.sort_values(by='bmi', ascending=False)
# Out:
#       age     sex     bmi  children smoker     region      charges type_bmi  \
# 1317   18    male  53.130         0     no  southeast   1163.46270     high
# 1047   22    male  52.580         1    yes  southeast  44501.39820     high
# 847    23    male  50.380         1     no  southeast   2438.05520     high
# 116    58    male  49.060         0     no  southeast  11381.32540     high
# 286    46  female  48.070         2     no  northeast   9432.92530     high
# ...   ...     ...     ...       ...    ...        ...          ...      ...
# 1286   28  female  17.290         0     no  northeast   3732.62510     high
# 412    26  female  17.195         2    yes  northeast  14455.64405     high
# 1226   38    male  16.815         2     no  northeast   6640.54485     high
# 428    21  female  16.815         1     no  northeast   3167.45585     high
# 172    18    male  15.960         0     no  northeast   1694.79640     high
#
#       rank_bmi new_region
# 1317    1338.0  SOUTHEAST
# ...

# %%
df.sort_index()
# Out:
#       age     sex     bmi  children smoker     region      charges type_bmi  \
# 0      19  female  27.900         0    yes  southwest  16884.92400      low
# 1      18    male  33.770         1     no  southeast   1725.55230   middle
# 2      28    male  33.000         3     no  southeast   4449.46200   middle
# 3      33    male  22.705         0     no  northwest  21984.47061      low
# 4      32    male  28.880         0     no  northwest   3866.85520      low
# ...   ...     ...     ...       ...    ...        ...          ...      ...
# 1333   50    male  30.970         3     no  northwest  10600.54830     high
# 1334   18  female  31.920         0     no  northeast   2205.98080   middle
# 1335   18  female  36.850         0     no  southeast   1629.83350   middle
# 1336   21  female  25.800         0     no  southwest   2007.94500      low
# 1337   61  female  29.070         0    yes  northwest  29141.36030      low
#
#       rank_bmi new_region
# 0        459.0  SOUTHWEST
# ...

# %%
df.loc[
    (df['sex'] == 'male') & 
    (df['age'] > 60) & 
    (df['bmi'] > 30) & 
    (df['smoker'] == 'no') &
    (df['children'] == 0)
]
# Out:
#       age   sex     bmi  children smoker     region      charges type_bmi  \
# 170    63  male  41.470         0     no  southeast  13405.39030     high
# 190    61  male  31.570         0     no  southeast  12557.60530   middle
# 335    64  male  34.500         0     no  southwest  13822.80300   middle
# 341    62  male  30.020         0     no  northwest  13352.09980     high
# 343    63  male  36.765         0     no  northeast  13981.85035   middle
# 493    61  male  43.400         0     no  southwest  12574.04900     high
# 534    64  male  40.480         0     no  southeast  13831.11520     high
# 550    63  male  30.800         0     no  southwest  13390.55900     high
# 635    64  male  38.190         0     no  northeast  14410.93210   middle
# 642    61  male  33.915         0     no  northeast  13143.86485   middle
# 722    62  male  37.400         0     no  southwest  12979.35800   middle
# 752    64  male  37.905         0     no  northwest  14210.53595   middle
# ...

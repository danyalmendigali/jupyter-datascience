# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('/Users/danialmendigali/Data Science background/course /Pandas Foundations/data sets /Pokemon.csv')

# %%
df.head()
# Out:
#    number                 name  type1   type2  total  hp  attack  defense  \
# 0       1            Bulbasaur  Grass  Poison    318  45      49       49
# 1       2              Ivysaur  Grass  Poison    405  60      62       63
# 2       3             Venusaur  Grass  Poison    525  80      82       83
# 3       3        Mega Venusaur  Grass  Poison    625  80     100      123
# 4       3  Gigantamax Venusaur  Grass  Poison    525  80      82       83
#
#    sp_attack  sp_defense  speed  generation  legendary
# 0         65          65     45           1      False
# 1         80          80     60           1      False
# 2        100         100     80           1      False
# 3        122         120     80           1      False
# 4        100         100     80           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1072 entries, 0 to 1071
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   number      1072 non-null   int64
#  1   name        1072 non-null   object
#  2   type1       1072 non-null   object
#  3   type2       574 non-null    object
#  4   total       1072 non-null   int64
#  5   hp          1072 non-null   int64
#  6   attack      1072 non-null   int64
#  7   defense     1072 non-null   int64
#  8   sp_attack   1072 non-null   int64
#  9   sp_defense  1072 non-null   int64
#  10  speed       1072 non-null   int64
#  11  generation  1072 non-null   int64
#  12  legendary   1072 non-null   bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 101.7+ KB

# %%
df.describe()
# Out:
#             number        total           hp       attack      defense  \
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean    445.219216   440.885261    70.486940    80.938433    74.968284
# std     267.772806   121.379077    26.868039    32.463582    31.208059
# min       1.000000   175.000000     1.000000     5.000000     5.000000
# 25%     209.750000   330.000000    50.000000    56.000000    52.000000
# 50%     442.500000   460.500000    68.000000    80.000000    70.000000
# 75%     681.250000   519.250000    84.000000   100.000000    90.000000
# max     898.000000  1125.000000   255.000000   190.000000   250.000000
#
#          sp_attack   sp_defense        speed   generation
# count  1072.000000  1072.000000  1072.000000  1072.000000
# mean     73.273321    72.476679    68.792910     4.294776
# std      32.643119    27.934253    30.076281     2.346472
# min      10.000000    20.000000     5.000000     0.000000
# ...

# %%
(df['attack'] > 150).sum()
# Out:
# np.int64(24)

# %%
slow_pokemons_df = df.loc[df["speed"] <= 10].count()
slow_pokemons_df
# Out:
# number        7
# name          7
# type1         7
# type2         2
# total         7
# hp            7
# attack        7
# defense       7
# sp_attack     7
# sp_defense    7
# speed         7
# generation    7
# legendary     7
# dtype: int64

# %%
sns.boxplot(data=df, x='speed')
# Out:
# <Axes: xlabel='speed'>

# %%
sns.boxplot(data=df, x='sp_defense')
# Out:
# <Axes: xlabel='sp_defense'>

# %%
(df['sp_defense'] <= 25).sum()
# Out:
# np.int64(20)

# %%
df.loc[df["sp_defense"] <= 25].shape
# Out:
# (20, 13)

# %%
legendary_df = (df['legendary'] == True).sum()
legendary_df
# Out:
# np.int64(118)

# %%
legendary_df = df.loc[df['legendary']]
legendary_df.head()
# Out:
#      number               name     type1   type2  total  hp  attack  defense  \
# 194     144           Articuno       Ice  Flying    580  90      85      100
# 195     144  Galarian Articuno   Psychic  Flying    580  90      85       85
# 196     145             Zapdos  Electric  Flying    580  90      90       85
# 197     145    Galarian Zapdos  Fighting  Flying    580  90     125       90
# 198     146            Moltres      Fire  Flying    580  90     100       90
#
#      sp_attack  sp_defense  speed  generation  legendary
# 194         95         125     85           1       True
# 195        125         100     95           8       True
# 196        125          90    100           1       True
# 197         85          90    100           8       True
# 198        125          85     90           1       True

# %%
ax = sns.scatterplot(data=df, x="defense", y="attack")
ax.annotate(
    "Who's this guy?", xy=(228, 10), xytext=(150, 10), color='red',
    arrowprops=dict(arrowstyle="->", color='red') 
)
# Out:
# Text(150, 10, "Who's this guy?")

# %%
df.head()
# Out:
#    number                 name  type1   type2  total  hp  attack  defense  \
# 0       1            Bulbasaur  Grass  Poison    318  45      49       49
# 1       2              Ivysaur  Grass  Poison    405  60      62       63
# 2       3             Venusaur  Grass  Poison    525  80      82       83
# 3       3        Mega Venusaur  Grass  Poison    625  80     100      123
# 4       3  Gigantamax Venusaur  Grass  Poison    525  80      82       83
#
#    sp_attack  sp_defense  speed  generation  legendary
# 0         65          65     45           1      False
# 1         80          80     60           1      False
# 2        100         100     80           1      False
# 3        122         120     80           1      False
# 4        100         100     80           1      False

# %%
df.sort_values(by=['defense', 'attack'], ascending=[False, True]).head()
# Out:
#       number                 name   type1   type2  total   hp  attack  \
# 1057     890  Eternamax Eternatus  Poison  Dragon   1125  255     115
# 272      213              Shuckle     Bug    Rock    505   20      10
# 266      208         Mega Steelix   Steel  Ground    610   75     125
# 378      306          Mega Aggron   Steel     NaN    630   70     140
# 947      805            Stakataka    Rock   Steel    570   61     131
#
#       defense  sp_attack  sp_defense  speed  generation  legendary
# 1057      250        125         250    130           8       True
# 272       230         10         230      5           2      False
# 266       230         55          95     30           2      False
# 378       230         60          80     50           3      False
# 947       211         53         101     13           7      False

# %%
sum((df['type1'] == 'Fire'))
# Out:
# 67

# %%
sum((df['type2'] == 'Flying'))
# Out:
# 114

# %%
sum(
    (df['type1'] == 'Fire') &
    (df['type2'] == 'Flying')
)
# Out:
# 8

# %%
df.loc[(
    (df['type1'] == 'Fire') &
    (df['type2'] == 'Flying')
)]
# Out:
#      number                  name type1   type2  total   hp  attack  defense  \
# 7         6             Charizard  Fire  Flying    534   78      84       78
# 9         6      Mega Charizard Y  Fire  Flying    634   78     104       78
# 10        6  Gigantamax Charizard  Fire  Flying    534   78      84       78
# 198     146               Moltres  Fire  Flying    580   90     100       90
# 313     250                 Ho-oh  Fire  Flying    680  106     130       90
# 782     662           Fletchinder  Fire  Flying    382   62      73       55
# 783     663            Talonflame  Fire  Flying    499   78      81       71
# 873     741  Oricorio Baile Style  Fire  Flying    476   75      70       70
#
#      sp_attack  sp_defense  speed  generation  legendary
# 7          109          85    100           1      False
# 9          159         115    100           1      False
# 10         109          85    100           1      False
# ...

# %%
df.query("`type1` == 'Fire' and `type2` == 'Flying'")
# Out:
#      number                  name type1   type2  total   hp  attack  defense  \
# 7         6             Charizard  Fire  Flying    534   78      84       78
# 9         6      Mega Charizard Y  Fire  Flying    634   78     104       78
# 10        6  Gigantamax Charizard  Fire  Flying    534   78      84       78
# 198     146               Moltres  Fire  Flying    580   90     100       90
# 313     250                 Ho-oh  Fire  Flying    680  106     130       90
# 782     662           Fletchinder  Fire  Flying    382   62      73       55
# 783     663            Talonflame  Fire  Flying    499   78      81       71
# 873     741  Oricorio Baile Style  Fire  Flying    476   75      70       70
#
#      sp_attack  sp_defense  speed  generation  legendary
# 7          109          85    100           1      False
# 9          159         115    100           1      False
# 10         109          85    100           1      False
# ...

# %%
df['type1'].value_counts()
# Out:
# type1
# Water        136
# Normal       117
# Grass         94
# Bug           83
# Psychic       80
# Fire          67
# Electric      63
# Rock          60
# Dark          48
# Fighting      45
# Ghost         43
# Poison        42
# Ground        42
# Dragon        41
# Steel         39
# Ice           38
# Fairy         23
# Flying         9
# Blastoise      1
# Graass         1
# Name: count, dtype: int64

# %%
df['type2'].value_counts()
# Out:
# type2
# Flying      114
# Fairy        44
# Psychic      43
# Poison       41
# Ground       39
# Steel        36
# Dragon       35
# Fighting     32
# Grass        29
# Dark         28
# Ghost        26
# Water        22
# Ice          19
# Fire         18
# Rock         16
# Normal       11
# Electric     11
# Bug          10
# Name: count, dtype: int64

# %%
df.query("`type1` == 'Poison' or `type2` == 'Poison'").shape
# Out:
# (83, 13)

# %%
sum((df['type1'] == 'Poison') | (df['type2'] == 'Poison'))
# Out:
# 83

# %%
df.loc[df['type1'] == 'Ice', 'defense'].max()
# Out:
# np.int64(184)

# %%
df.loc[
    (df['type1'] == 'Ice') & 
    (df['defense'] == df.loc[df['type1'] == 'Ice', 'defense'].max())
].iloc[0, 1]
# Out:
# 'Avalugg'

# %%
df.loc[df['legendary'], 'type1'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='type1'>

# %%
df.head()
# Out:
#    number                 name  type1   type2  total  hp  attack  defense  \
# 0       1            Bulbasaur  Grass  Poison    318  45      49       49
# 1       2              Ivysaur  Grass  Poison    405  60      62       63
# 2       3             Venusaur  Grass  Poison    525  80      82       83
# 3       3        Mega Venusaur  Grass  Poison    625  80     100      123
# 4       3  Gigantamax Venusaur  Grass  Poison    525  80      82       83
#
#    sp_attack  sp_defense  speed  generation  legendary
# 0         65          65     45           1      False
# 1         80          80     60           1      False
# 2        100         100     80           1      False
# 3        122         120     80           1      False
# 4        100         100     80           1      False

# %%
df.loc[df['type1'] == 'Water'].head()
# Out:
#     number            name  type1 type2  total  hp  attack  defense  \
# 11       7        Squirtle  Water   NaN    314  44      48       65
# 12       8       Wartortle  Water   NaN    405  59      63       80
# 13       9       Blastoise  Water   NaN    530  79      83      100
# 14       9  Mega Blastoise  Water   NaN    630  79     103      120
# 77      54         Psyduck  Water   NaN    320  50      52       48
#
#     sp_attack  sp_defense  speed  generation  legendary
# 11         50          64     43           1      False
# 12         65          80     58           1      False
# 13         85         105     78           1      False
# 14        135         115     78           1      False
# 77         65          50     55           1      False

# %%
df['generation'].value_counts(sort=False)
# Out:
# generation
# 1    178
# 7    114
# 8    139
# 2    106
# 3    160
# 4    121
# 5    166
# 6     85
# 0      3
# Name: count, dtype: int64

# %%
df['generation'].value_counts(sort=False).plot(kind='bar')
# Out:
# <Axes: xlabel='generation'>

# %%
df.loc[
    (df['type1'] == 'Water') &
    df['generation'].isin([1, 2, 3])
].sort_values(by='total', ascending=False).head()
# Out:
#      number            name  type1   type2  total   hp  attack  defense  \
# 467     382   Primal Kyogre  Water     NaN    770  100     150       90
# 466     382          Kyogre  Water     NaN    670  100     100       90
# 176     130   Mega Gyarados  Water    Dark    640   95     155      109
# 326     260   Mega Swampert  Water  Ground    635  100     150      110
# 14        9  Mega Blastoise  Water     NaN    630   79     103      120
#
#      sp_attack  sp_defense  speed  generation  legendary
# 467        180         160     90           3       True
# 466        150         140     90           3       True
# 176         70         130     81           1      False
# 326         95         110     70           3      False
# 14         135         115     78           1      False

# %%
df.loc[df['type1'].isin(['Fire', 'Water'])]
# Out:
#       number                    name  type1   type2  total   hp  attack  \
# 5          4              Charmander   Fire     NaN    309   39      52
# 6          5              Charmeleon   Fire     NaN    405   58      64
# 7          6               Charizard   Fire  Flying    534   78      84
# 8          6        Mega Charizard X   Fire  Dragon    634   78     130
# 9          6        Mega Charizard Y   Fire  Flying    634   78     104
# ...      ...                     ...    ...     ...    ...  ...     ...
# 1005     850              Sizzlipede   Fire     Bug    305   50      65
# 1006     851             Centiskorch   Fire     Bug    525  100     115
# 1007     851  Gigantamax Centiskorch   Fire     Bug    525  100     115
# 1045     882               Dracovish  Water  Dragon    505   90      90
# 1046     883               Arctovish  Water     Ice    505   90      90
#
#       defense  sp_attack  sp_defense  speed  generation  legendary
# ...

# %%
sum((
    (df['generation'] == 1) | 
    (df['generation'] == 2) |
    (df['generation'] == 3)
))
# Out:
# 444

# %%
sum(df['generation'].isin([1, 2, 3 ]))
# Out:
# 444

# %%
df.loc[df['type1'] == 'Water'].head()
# Out:
#     number            name  type1 type2  total  hp  attack  defense  \
# 11       7        Squirtle  Water   NaN    314  44      48       65
# 12       8       Wartortle  Water   NaN    405  59      63       80
# 13       9       Blastoise  Water   NaN    530  79      83      100
# 14       9  Mega Blastoise  Water   NaN    630  79     103      120
# 77      54         Psyduck  Water   NaN    320  50      52       48
#
#     sp_attack  sp_defense  speed  generation  legendary
# 11         50          64     43           1      False
# 12         65          80     58           1      False
# 13         85         105     78           1      False
# 14        135         115     78           1      False
# 77         65          50     55           1      False

# %%
df['generation'].value_counts()
# Out:
# generation
# 1    178
# 5    166
# 3    160
# 8    139
# 4    121
# 7    114
# 2    106
# 6     85
# 0      3
# Name: count, dtype: int64

# %%
df.loc[
    ((df['type1'] == 'Dragon') | (df['type2'] == 'Dragon')) &
    (df['generation'].isin({8, 7}))
].sort_values(by='total', ascending=False)
# Out:
#       number                  name     type1     type2  total   hp  attack  \
# 1057     890   Eternamax Eternatus    Poison    Dragon   1125  255     115
# 942      800        Ultra Necrozma   Psychic    Dragon    754   97     167
# 1056     890             Eternatus    Poison    Dragon    690  140      85
# 1051     887             Dragapult    Dragon     Ghost    600   88     120
# 923      784               Kommo-o    Dragon  Fighting    600   75     110
# 1066     895             Regidrago    Dragon       NaN    580  200     100
# 938      799              Guzzlord      Dark    Dragon    570  223     101
# 946      804             Naganadel    Poison    Dragon    540   73      73
# 1047     884             Duraludon     Steel    Dragon    535   70      95
# 1048     884  Gigantamax Duraludon     Steel    Dragon    535   70      95
# 143      103      Alolan Exeggutor     Grass    Dragon    530   95     105
# ...

# %%
sum((
    (df['attack'] > 100) &
    (df['type1'] == 'Fire') 
))
# Out:
# 19

# %%
powerful_fire_df = df.query("`attack` > 100 and `type1` == 'Fire'")
powerful_fire_df
# Out:
#       number                      name type1     type2  total   hp  attack  \
# 8          6          Mega Charizard X  Fire    Dragon    634   78     130
# 9          6          Mega Charizard Y  Fire    Flying    634   78     104
# 82        59                  Arcanine  Fire       NaN    555   90     110
# 184      136                   Flareon  Fire       NaN    525   65     130
# 306      244                     Entei  Fire       NaN    580  115     115
# 313      250                     Ho-oh  Fire    Flying    680  106     130
# 321      257                  Blaziken  Fire  Fighting    530   80     120
# 322      257             Mega Blaziken  Fire  Fighting    630   80     160
# 399      323             Mega Camerupt  Fire    Ground    560   70     120
# 482      392                 Infernape  Fire  Fighting    534   76     104
# 604      500                    Emboar  Fire  Fighting    528  110     123
# ...

# %%
water_flying_df = df.query("`type1` == 'Water' and `type2` == 'Flying'")
water_flying_df
# Out:
#      number      name  type1   type2  total  hp  attack  defense  sp_attack  \
# 175     130  Gyarados  Water  Flying    540  95     125       79         60
# 287     226   Mantine  Water  Flying    465  65      40       70         80
# 346     278   Wingull  Water  Flying    270  40      30       30         55
# 347     279  Pelipper  Water  Flying    430  60      50      100         85
# 553     458   Mantyke  Water  Flying    345  45      20       50         60
# 691     580  Ducklett  Water  Flying    305  62      44       50         44
# 692     581    Swanna  Water  Flying    473  75      87       63         87
#
#      sp_defense  speed  generation  legendary
# 175         100     81           1      False
# 287         140     70           2      False
# 346          30     85           3      False
# 347          70     65           3      False
# 553         120     50           4      False
# 691          50     55           5      False
# ...

# %%
df.loc[
    (CONDITIONALS FOR INDEX),
    (COLUMNS)
]

# %%
legendary_fire_df = df.loc[
    (df['type1'] == 'Fire') & df['legendary'], ['name', 'attack','generation']
]
legendary_fire_df
# Out:
#           name  attack  generation
# 198    Moltres     100           1
# 306      Entei     115           2
# 313      Ho-oh     130           2
# 587    Heatran      90           4
# 853  Volcanion     110           6

# %%
ax = df['speed'].plot(kind='hist', figsize=(10, 5), bins=100)
ax.axvline(df['speed'].quantile(.05), color='red')
ax.axvline(df['speed'].quantile(.95), color='red')

# %%
bottom_5 = df['speed'].quantile(.05)
top_5 = df['speed'].quantile(.95)
(bottom_5, top_5)
# Out:
# (np.float64(25.0), np.float64(120.0))

# %%
df.query("speed < @bottom_5 or speed > @top_5")
# Out:
#       number                  name     type1   type2  total   hp  attack  \
# 23        15         Mega Beedrill       Bug  Poison    495   65     150
# 27        18          Mega Pidgeot    Normal  Flying    579   83      80
# 56        39            Jigglypuff    Normal   Fairy    270  115      45
# 89        65         Mega Alakazam   Psychic     NaN    590   55      50
# 99        74               Geodude      Rock  Ground    300   40      80
# ...      ...                   ...       ...     ...    ...  ...     ...
# 1056     890             Eternatus    Poison  Dragon    690  140      85
# 1057     890   Eternamax Eternatus    Poison  Dragon   1125  255     115
# 1065     894             Regieleki  Electric     NaN    580   80     100
# 1068     897             Spectrier     Ghost     NaN    580  100      65
# 1071     898  Shadow Rider Calyrex   Psychic   Ghost    680  100      85
#
#       defense  sp_attack  sp_defense  speed  generation  legendary
# ...

# %%
slow_fast_df = df.loc[(df['speed'] < bottom_5) | (df['speed'] > top_5)]
slow_fast_df
# Out:
#       number                  name     type1   type2  total   hp  attack  \
# 23        15         Mega Beedrill       Bug  Poison    495   65     150
# 27        18          Mega Pidgeot    Normal  Flying    579   83      80
# 56        39            Jigglypuff    Normal   Fairy    270  115      45
# 89        65         Mega Alakazam   Psychic     NaN    590   55      50
# 99        74               Geodude      Rock  Ground    300   40      80
# ...      ...                   ...       ...     ...    ...  ...     ...
# 1056     890             Eternatus    Poison  Dragon    690  140      85
# 1057     890   Eternamax Eternatus    Poison  Dragon   1125  255     115
# 1065     894             Regieleki  Electric     NaN    580   80     100
# 1068     897             Spectrier     Ghost     NaN    580  100      65
# 1071     898  Shadow Rider Calyrex   Psychic   Ghost    680  100      85
#
#       defense  sp_attack  sp_defense  speed  generation  legendary
# ...

# %%
df.loc[df['legendary']].sort_values(by=['attack', 'defense'], ascending=False)
# Out:
#       number                        name    type1     type2  total   hp  \
# 204      150               Mega Mewtwo X  Psychic  Fighting    780  106
# 469      383              Primal Groudon   Ground      Fire    770  100
# 471      384               Mega Rayquaza   Dragon    Flying    780  105
# 474      386         Deoxys Attack Forme  Psychic       NaN    600   50
# 1053     888  Zacian Crowned Sword Forme    Fairy     Steel    720   92
# ...      ...                         ...      ...       ...    ...  ...
# 950      808                      Meltan    Steel       NaN    300   46
# 1068     897                   Spectrier    Ghost       NaN    580  100
# 460      378                      Regice      Ice       NaN    580   80
# 929      790                     Cosmoem  Psychic       NaN    400   43
# 928      789                      Cosmog  Psychic       NaN    200   43
#
#       attack  defense  sp_attack  sp_defense  speed  generation  legendary
# ...

# %%
import pandas as pd

# %%
words = pd.read_csv("popular.csv")

# %%
words
# Out:
#              aa
# 0      aardvark
# 1         aargh
# 2         aback
# 3        abacus
# 4       abandon
# ...         ...
# 25316    zoning
# 25317    zonked
# 25318       zoo
# 25319      zoom
# 25320   zooming
#
# [25321 rows x 1 columns]

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/Users/danialmendigali/jupyter-datascience/Pandas/data set /Titanic-Dataset.csv')

# %% [markdown]
# ### Block 1

# %%
n = df.isnull().sum()
n
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.loc[
    (df['Age'] > 20) &
    (df['Sex'] == 'male') &
    (df['Name'].str.contains('q'))
]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 137          138         0       1   Futrelle, Mr. Jacques Heath  male  37.0
# 271          272         1       3  Tornquist, Mr. William Henry  male  25.0
# 292          293         0       2        Levy, Mr. Rene Jacques  male  36.0
#
#      SibSp  Parch         Ticket    Fare Cabin Embarked
# 137      1      0         113803  53.100  C123        S
# 271      0      0           LINE   0.000   NaN        S
# 292      0      0  SC/Paris 2163  12.875     D        C

# %%
df.loc[
    (df['Age'] > 20) &
    (df['Sex'] == 'male') &
    (df['Name'].str.contains('q'))
].isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 137        False     False   False  False  False  False  False  False   False
# 271        False     False   False  False  False  False  False  False   False
# 292        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 137  False  False     False
# 271  False   True     False
# 292  False  False     False

# %%
df.duplicated(subset='Ticket').sum()
# Out:
# np.int64(210)

# %%
df.shape[0]
# Out:
# 89

# %%
df = df.drop_duplicates(subset='Age')

# %%
nm = df.isnull().sum()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t = df.pivot_table(index='Sex', values='Age', aggfunc=['mean', 'max'])

# %%
t.reset_index()
# Out:
#       Sex       mean   max
#                  Age   Age
# 0  female  27.915709  63.0
# 1    male  30.726645  80.0

# %%
t.columns = ['__'.join(col).strip() for col in t.columns.values]

# %%
t
# Out:
#         mean__Age  max__Age
# Sex
# female  27.915709      63.0
# male    30.726645      80.0

# %%
t2 = df.pivot_table(index='Embarked', values='Age', aggfunc=['mean', 'min'])

# %%
t3 = df.pivot_table(index='Ticket', values='Fare', aggfunc=['mean', 'max'])

# %%
t2.head()
# Out:
#                mean   min
#                 Age   Age
# Embarked
# C         30.814769  0.42
# Q         28.089286  2.00
# S         29.445397  0.67

# %%
t3.tail(5)
# Out:
#                mean     max
#                Fare    Fare
# Ticket
# W./C. 6608   34.375  34.375
# W./C. 6609    7.550   7.550
# W.E.P. 5734  61.175  61.175
# W/C 14208    10.500  10.500
# WE/P 5735    71.000  71.000

# %%
t4 = df.pivot_table(index='Survived', values='Age', aggfunc=['mean', 'max', 'min'])

# %%
t4
# Out:
#                mean   max   min
#                 Age   Age   Age
# Survived
# 0         30.626179  74.0  1.00
# 1         28.343690  80.0  0.42

# %% [markdown]
# # Средний возраст тех кто не выжил он больше чем тех кто выжил, это указывает на примущество молодых пассажиров

# %%
t5 = df.pivot_table(index='Pclass',  values='Age', aggfunc=['mean', 'max'])
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
t5
# Out:
#         mean__Age  max__Age
# Pclass
# 1       38.233441      80.0
# 2       29.877630      70.0
# 3       25.140620      74.0

# %%
t5.columns = ['__'.join(col).strip() for col in t5.columns.values]

# %% [markdown]
# # Возраст пассажиров 1 класса значительно выше чем у пассажиров 2 и 3 класса

# %%
t6 = df.groupby(['Pclass', 'Survived']).size().unstack()
t6
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %% [markdown]
# # Больше людей выжило чем погибло только в первом классе

# %% [markdown]
# ### Block 2 (sort_values, sort_indexrank)

# %%
df = pd.read_csv('/Users/danialmendigali/jupyter-datascience/Pandas/data set /Titanic-Dataset.csv')

# %%
df.sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values('Age', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values(
    by = ['Pclass', 'Age'],
    ascending=[True, False]
).head(10)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 456          457         0       1             Millet, Mr. Francis Davis
# 438          439         0       1                     Fortune, Mr. Mark
# 545          546         0       1          Nicholson, Mr. Arthur Ernest
# 275          276         1       1     Andrews, Miss. Kornelia Theodosia
# 252          253         0       1             Stead, Mr. William Thomas
#
#         Sex   Age  SibSp  Parch     Ticket      Fare        Cabin Embarked
# 630    male  80.0      0      0      27042   30.0000          A23        S
# ...

# %%
df.sort_values('Cabin', na_position='last')
# Out:
#      PassengerId  Survived  Pclass  \
# 583          584         0       1
# 475          476         0       1
# 556          557         1       1
# 284          285         0       1
# 599          600         1       1
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 583                                Ross, Mr. John Hugo    male  36.0      0
# 475                        Clifford, Mr. George Quincy    male   NaN      0
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female  48.0      1
# 284                         Smith, Mr. Richard William    male   NaN      0
# 599       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values('Cabin', na_position='first')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# ..           ...       ...     ...
# 394          395         1       3
# 10            11         1       3
# 205          206         0       3
# 251          252         0       3
# 339          340         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby('Pclass')['Age'].mean().sort_index()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
df.groupby(['Pclass', 'Sex'])['Survived'].mean().sort_index(ascending=False)
# Out:
# Pclass  Sex
# 3       male      0.135447
#         female    0.500000
# 2       male      0.157407
#         female    0.921053
# 1       male      0.368852
#         female    0.968085
# Name: Survived, dtype: float64

# %%
df.groupby(['Survived', 'Sex'])['Age'].mean().sort_index()
# Out:
# Survived  Sex
# 0         female    25.046875
#           male      31.618056
# 1         female    28.847716
#           male      27.276022
# Name: Age, dtype: float64

# %% [markdown]
# #### rank()

# %%
df1 = pd.read_csv('/Users/danialmendigali/jupyter-datascience/Pandas/data set /nba.csv')

# %%
df1.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
df1['Rank'] = df1['Name'].rank()

# %%
df1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary   Rank
# 0                Texas  7730337.0   35.0
# ...

# %%
df1.sort_values('Name', inplace=True)

# %%
df1
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# ..              ...                     ...     ...      ...   ...    ...
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary   Rank
# ...

# %%
df1.sort_values('Team', inplace=True)

# %%
df1['Rank'] = df1['Team'].rank(method='min')
df1
# Out:
#                 Name                Team  Number Position   Age Height  \
# 318  Dennis Schroder       Atlanta Hawks    17.0       PG  22.0    6-1
# 309    Kent Bazemore       Atlanta Hawks    24.0       SF  26.0    6-5
# 311     Kirk Hinrich       Atlanta Hawks    12.0       SG  35.0    6-4
# 313   Kris Humphries       Atlanta Hawks    43.0       PF  31.0    6-9
# 314      Kyle Korver       Atlanta Hawks    26.0       SG  35.0    6-7
# ..               ...                 ...     ...      ...   ...    ...
# 371     Jarell Eddie  Washington Wizards     8.0       SG  24.0    6-7
# 372      Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10
# 382        John Wall  Washington Wizards     2.0       PG  25.0    6-4
# 370     Jared Dudley  Washington Wizards     1.0       SF  30.0    6-7
# 457              NaN                 NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary   Rank
# 318   172.0             NaN   1763400.0    1.0
# ...

# %%
df1['Rank'] = df1['Team'].rank(method='average')
df1
# Out:
#                 Name                Team  Number Position   Age Height  \
# 318  Dennis Schroder       Atlanta Hawks    17.0       PG  22.0    6-1
# 309    Kent Bazemore       Atlanta Hawks    24.0       SF  26.0    6-5
# 311     Kirk Hinrich       Atlanta Hawks    12.0       SG  35.0    6-4
# 313   Kris Humphries       Atlanta Hawks    43.0       PF  31.0    6-9
# 314      Kyle Korver       Atlanta Hawks    26.0       SG  35.0    6-7
# ..               ...                 ...     ...      ...   ...    ...
# 371     Jarell Eddie  Washington Wizards     8.0       SG  24.0    6-7
# 372      Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10
# 382        John Wall  Washington Wizards     2.0       PG  25.0    6-4
# 370     Jared Dudley  Washington Wizards     1.0       SF  30.0    6-7
# 457              NaN                 NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary   Rank
# 318   172.0             NaN   1763400.0    8.0
# ...

# %%
df.sort_values(['Age', 'Fare'], ascending=[False, True])
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 851          852         0       3
# 96            97         0       1
# 493          494         0       1
# 116          117         0       3
# ..           ...       ...     ...
# 306          307         1       1
# 334          335         1       1
# 31            32         1       1
# 527          528         0       1
# 557          558         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 630               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 851                                Svensson, Mr. Johan    male  74.0      0
# 96                           Goldschmidt, Mr. George B    male  71.0      0
# 493                            Artagaveytia, Mr. Ramon    male  71.0      0
# 116                               Connors, Mr. Patrick    male  70.5      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values('Age', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values('Age', ascending=False).head(10)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 280          281         0       3                      Duane, Mr. Frank
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0       27042  30.0000   A23        S
# ...

# %%
df.sort_values('Fare').tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 299          300         1       1
# 742          743         1       1
# 311          312         1       1
# 27            28         0       1
# 88            89         1       1
# 438          439         0       1
# 341          342         1       1
# 737          738         1       1
# 258          259         1       1
# 679          680         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 742            Ryerson, Miss. Susan Parker "Suzette"  female  21.0      2
# 311                       Ryerson, Miss. Emily Borie  female  18.0      2
# 27                    Fortune, Mr. Charles Alexander    male  19.0      3
# 88                        Fortune, Miss. Mabel Helen  female  23.0      3
# 438                                Fortune, Mr. Mark    male  64.0      1
# ...

# %%
df['rank_*'] = df['Fare'].rank()

# %%
df.groupby(['Pclass', 'Sex'])['Age'].mean().sort_index(ascending=True)
# Out:
# Pclass  Sex
# 1       female    34.611765
#         male      41.281386
# 2       female    28.722973
#         male      30.740707
# 3       female    21.750000
#         male      26.507589
# Name: Age, dtype: float64

# %% [markdown]
# ### Block 3 (.index, set_index, reset_index, loc vs iloc)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df_name = df.set_index('Name')
df_name.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
df_id = df.set_index('PassengerId')
df_id.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  rank_*
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    77.0
# 2                1      0          PC 17599  71.2833   C85        C   789.0
# ...

# %%
df[df['PassengerId'] == 10]
# Out:
#    PassengerId  Survived  Pclass                                 Name     Sex  \
# 9           10         1       2  Nasser, Mrs. Nicholas (Adele Achem)  female
#
#     Age  SibSp  Parch  Ticket     Fare Cabin Embarked  rank_*
# 9  14.0      1      0  237736  30.0708   NaN        C   658.5

# %%
t = df.groupby('Sex')['Age'].mean().reset_index()
t
# Out:
#       Sex        Age
# 0  female  27.915709
# 1    male  30.726645

# %%
df.loc[df['Age'] > 60, ['Name', 'Age']].head(5)
# Out:
#                                Name   Age
# 33            Wheadon, Mr. Edward H  66.0
# 54   Ostby, Mr. Engelhart Cornelius  65.0
# 96        Goldschmidt, Mr. George B  71.0
# 116            Connors, Mr. Patrick  70.5
# 170       Van der hoef, Mr. Wyckoff  61.0

# %%
df.loc[10]
# Out:
# PassengerId                                 11
# Survived                                     1
# Pclass                                       3
# Name           Sandstrom, Miss. Marguerite Rut
# Sex                                     female
# Age                                        4.0
# SibSp                                        1
# Parch                                        1
# Ticket                                 PP 9549
# Fare                                      16.7
# Cabin                                       G6
# Embarked                                     S
# rank_*                                   495.5
# Name: 10, dtype: object

# %%
df.loc[:, ['Name', 'Age', 'Survived']]
# Out:
#                                                   Name   Age  Survived
# 0                              Braund, Mr. Owen Harris  22.0         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0         1
# 2                               Heikkinen, Miss. Laina  26.0         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0         1
# 4                             Allen, Mr. William Henry  35.0         0
# ..                                                 ...   ...       ...
# 886                              Montvila, Rev. Juozas  27.0         0
# 887                       Graham, Miss. Margaret Edith  19.0         1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN         0
# 889                              Behr, Mr. Karl Howell  26.0         1
# 890                                Dooley, Mr. Patrick  32.0         0
#
# [891 rows x 3 columns]

# %%
df.loc[(df['Sex'] == 'female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
###   df.iloc[строки, колонки]
df.iloc[1:5, 1:13]
# Out:
#    Survived  Pclass                                               Name  \
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    rank_*
# 1   789.0
# 2   232.5
# 3   748.0
# 4   264.0

# %%
df.iloc[:, 1:5]
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# ...

# %%
df.iloc[1:5, :]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  rank_*
# 1      0          PC 17599  71.2833   C85        C   789.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S   232.5
# 3      0            113803  53.1000  C123        S   748.0
# 4      0            373450   8.0500   NaN        S   264.0

# %%
df = df.set_index('Name')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/xz/rfbft5295y53fp00snkfjx900000gn/T/ipykernel_44826/701191181.py in ?()
# ----> 1 df = df.set_index('Name')
#       2 df
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['Name'] are in the columns"

# %%
df.reset_index().head(5)
# Out:
#       Sex  PassengerId  Survived  Pclass   Age  SibSp  Parch  \
# 0    male            1         0       3  22.0      1      0
# 1  female            2         1       1  38.0      1      0
# 2  female            3         1       3  26.0      0      0
# 3  female            4         1       1  35.0      1      0
# 4    male            5         0       3  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df = df.set_index('Sex')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/xz/rfbft5295y53fp00snkfjx900000gn/T/ipykernel_44826/1959127125.py in ?()
# ----> 1 df = df.set_index('Sex').tail(5)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['Sex'] are in the columns"

# %%
df.reset_index()
# Out:
#         Sex  PassengerId  Survived  Pclass   Age  SibSp  Parch  \
# 0      male            1         0       3  22.0      1      0
# 1    female            2         1       1  38.0      1      0
# 2    female            3         1       3  26.0      0      0
# 3    female            4         1       1  35.0      1      0
# 4      male            5         0       3  35.0      0      0
# ..      ...          ...       ...     ...   ...    ...    ...
# 886    male          887         0       2  27.0      0      0
# 887  female          888         1       1  19.0      0      0
# 888  female          889         0       3   NaN      1      2
# 889    male          890         1       1  26.0      0      0
# 890    male          891         0       3  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.loc[(df['Name'].str.startswith('G')) & (df['Age'] > 50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 96            97         0       1
# 222          223         0       3
# 268          269         1       1
# 714          715         0       2
#
#                                               Name     Sex   Age  SibSp  \
# 96                       Goldschmidt, Mr. George B    male  71.0      0
# 222                        Green, Mr. George Henry    male  51.0      0
# 268  Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 714                          Greenberg, Mr. Samuel    male  52.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 96       0  PC 17754   34.6542    A5        C
# 222      0     21440    8.0500   NaN        S
# 268      1  PC 17582  153.4625  C125        S
# 714      0    250647   13.0000   NaN        S

# %%
## .loc позволяет обращаться к строкам и колонкам и изменять их значения
## df.loc[условие_для_строк, 'колонка'] = новое_значение

# %%
df.loc[df['Age'] < 1, 'Age'] = 1

# %%
df.sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 386          387         0       3           Goodwin, Master. Sidney Leonard
# 831          832         1       2           Richards, Master. George Sibley
# 827          828         1       2                     Mallet, Master. Andre
# 381          382         1       3               Nakid, Miss. Maria ("Mary")
# 164          165         0       3              Panula, Master. Eino Viljami
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

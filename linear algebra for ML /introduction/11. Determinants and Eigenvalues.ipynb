# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt 
import torch
# Out:
# /Users/danialmendigali/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
def plot_vectors(vectors, colors):
    plt.figure()
    plt.axvline(x = 0, color='lightgray')
    plt.axhline(y = 0, color='lightgray')
    for i in range(len(vectors)):
        x = np.concatenate([[0, 0], vectors[i]])
        plt.quiver([x[0]], [x[1]], [x[2]], [x[3]],
            angles='xy', scale_units='xy', scale=1, color=colors[i],)

# %%
def vectorfy(mtrx, clmn):
    return np.array(mtrx[:, clmn]).reshape(-1)

# %%
a = np.array([[1, 2, 4], [2, -1, 3], [0, 5, 1]])
a
# Out:
# array([[ 1,  2,  4],
#        [ 2, -1,  3],
#        [ 0,  5,  1]])

# %%
np.linalg.det(a)
# Out:
# np.float64(19.999999999999996)

# %%
lambdas, v = np.linalg.eig(a)
lambdas
# Out:
# array([-3.25599251, -1.13863631,  5.39462882])

# %%
r = 1
for i in range(len(lambdas)):
    r *= lambdas[i]
print(r)
# Out:
# 19.99999999999999

# %%
np.abs(np.linalg.det(a))
# Out:
# np.float64(19.999999999999996)

# %%
b = np.array([[1, 0], [0, 1]])
b
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
plot_vectors([vectorfy(b, 0), vectorfy(b, 1)], ['lightblue', 'lightgreen'])
plt.xlim(-1, 3)
_ = plt.ylim(-1, 3)

# %%
n = torch.tensor([[-4, 1], [-8, 2.]])

# %%
n
# Out:
# tensor([[-4.,  1.],
#         [-8.,  2.]])

# %%
np.linalg.det(n)
# Out:
# np.float32(0.0)

# %%
nb = np.dot(n, b)
nb
# Out:
# /var/folders/xz/rfbft5295y53fp00snkfjx900000gn/T/ipykernel_15408/3700487750.py:1: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   nb = np.dot(n, b)
# array([[-4.,  1.],
#        [-8.,  2.]])

# %%
plot_vectors([vectorfy(b, 0), vectorfy(b, 1), vectorfy(nb, 0), vectorfy(nb, 1)], ['lightblue', 'lightgreen', 'blue', 'green'])
plt.xlim(-6, 6)
_ = plt.ylim(-9, 3)

# %%
lambdas, v = np.linalg.eig(n)
lambdas
# Out:
# array([-2.,  0.], dtype=float32)

# %%
I = np.array([[1, 0], [0, 1]])
I
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
np.linalg.det(I)
# Out:
# np.float64(1.0)

# %%
ib = np.dot(I, b)
ib
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
plot_vectors([vectorfy(b, 0), vectorfy(b, 1), vectorfy(ib, 0), vectorfy(ib, 1)], ['lightblue', 'lightgreen', 'blue', 'green'])
plt.xlim(-1, 3)
_ = plt.ylim(-1, 3)

# %%
lambdas,  v = np.linalg.eig(I)
lambdas
# Out:
# array([1., 1.])

# %%
j = np.array([[-0.5, 0], [0, 2]])
j
# Out:
# array([[-0.5,  0. ],
#        [ 0. ,  2. ]])

# %%
np.linalg.det(j)
# Out:
# np.float64(-1.0)

# %%
np.abs(np.linalg.det(j))
# Out:
# np.float64(1.0)

# %%
jb = np.dot(j, b)
jb
# Out:
# array([[-0.5,  0. ],
#        [ 0. ,  2. ]])

# %%
plot_vectors([vectorfy(b, 0), vectorfy(b, 1), vectorfy(jb, 0), vectorfy(jb, 1)], ['lightblue', 'lightgreen', 'blue', 'green'])
plt.xlim(-1, 3)
_ = plt.ylim(-1, 3)

# %%
lambdas, v = np.linalg.eig(j)
lambdas
# Out:
# array([-0.5,  2. ])

# %%
d = I * 2
d
# Out:
# array([[2, 0],
#        [0, 2]])

# %%
np.linalg.det(d)
# Out:
# np.float64(4.0)

# %%
db = np.dot(d, b)
db
# Out:
# array([[2, 0],
#        [0, 2]])

# %%
plot_vectors([vectorfy(b, 0), vectorfy(b, 1), vectorfy(db, 0), vectorfy(db, 1)], ['lightblue', 'lightgreen', 'blue', 'green'])
plt.xlim(-1, 3)
_ = plt.ylim(-1, 3)

# %%
lambdas, v = np.linalg.eig(d)
lambdas
# Out:
# array([2., 2.])

# %%
import numpy as np
import tensorflow as tf
import torch
# Out:
# /Users/danialmendigali/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
x = np.array([[1, 2], [3, 4]])
(1**2 + 2**2 + 3**2 + 4**2) **(1 / 2)
# Out:
# 5.477225575051661

# %%
np.linalg.norm(x)
# Out:
# np.float64(5.477225575051661)

# %%
x_pt = torch.tensor([[1, 2], [3, 4]])
torch.norm(x_pt)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 2
#       1 x_pt = torch.tensor([[1, 2], [3, 4]])
# ----> 2 torch.norm(x_pt)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/functional.py:1833, in norm(input, p, dim, keepdim, out, dtype)
#    1829 if p == "fro" and (
#    1830     dim is None or isinstance(dim, (int, torch.SymInt)) or len(dim) <= 2
#    1831 ):
#    1832     if out is None:
# -> 1833         return torch.linalg.vector_norm(
#    1834             input, 2, _dim, keepdim, dtype=dtype
#    1835         )
#    1836     else:
#    1837         return torch.linalg.vector_norm(
#    1838             input, 2, _dim, keepdim, dtype=dtype, out=out
#    1839         )
#
# RuntimeError: linalg.vector_norm: Expected a floating point or complex tensor as input. Got Long

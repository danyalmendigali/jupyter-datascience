# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt 
import torch

# %%
v = np.array([3, 1])
v
# Out:
# array([3, 1])

# %%
def plot_vectors(vectors, colors):
    plt.figure()
    plt.axvline(x = 0, color='lightgray')
    plt.axhline(y = 0, color='lightgray')
    for i in range(len(vectors)):
        x = np.concatenate([[0, 0], vectors[i]])
        plt.quiver([x[0]], [x[1]], [x[2]], [x[3]],
            angles='xy', scale_units='xy', scale=1, color=colors[i],)

# %%
plot_vectors([v], ['lightblue'])
plt.xlim(-1, 5)
_ = plt.ylim(-1, 5)

# %%
I = np.array([[1, 0], [0, 1]])
I
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
Iv = np.dot(I, v)
Iv
# Out:
# array([3, 1])

# %%
v == Iv
# Out:
# array([ True,  True])

# %%
plot_vectors([Iv], ['blue'])
plt.xlim(-1, 5)
_ = plt.ylim(-1, 5)

# %%
E = np.array([[1, 0], [0, -1]])
E
# Out:
# array([[ 1,  0],
#        [ 0, -1]])

# %%
Ev = np.dot(E, v)
Ev
# Out:
# array([ 3, -1])

# %%
plot_vectors([v, Ev], ['lightblue', 'blue'])
plt.xlim(-1, 5)
_ = plt.ylim(-3, 3)

# %%
F = np.array([[-1, 0], [0, 1]])
F
# Out:
# array([[-1,  0],
#        [ 0,  1]])

# %%
Fv = np.dot(F, v)
Fv
# Out:
# array([-3,  1])

# %%
plot_vectors([v, Fv], ['lightblue', 'blue'])
plt.xlim(-4, 4)
_ = plt.ylim(-1, 5)

# %%
A = np.array([[-1, 4], [2, -2]])
A
# Out:
# array([[-1,  4],
#        [ 2, -2]])

# %%
Av = np.dot(A, v)
Av
# Out:
# array([1, 4])

# %%
plot_vectors([v, Av], ['lightblue', 'blue'])
plt.xlim(-1, 5)
_ = plt.ylim(-1, 5)

# %%
v2 = np.array([2, 1])
plot_vectors([v2, np.dot(A, v2)], ['lightgreen', 'green'])
plt.xlim(-1, 5)
_ = plt.ylim(-1, 5)

# %%
v
# Out:
# array([3, 1])

# %%
np.matrix(v).T
# Out:
# matrix([[3],
#         [1]])

# %%
v3 = np.array([-3, -1])
v4 = np.array([-1, 1])

V = np.concatenate((np.matrix(v).T, np.matrix(v2).T, np.matrix(v3).T, np.matrix(v4).T), axis = 1)
V
# Out:
# matrix([[ 3,  2, -3, -1],
#         [ 1,  1, -1,  1]])

# %%
Iv = np.dot(I, V)

Iv
# Out:
# matrix([[ 3,  2, -3, -1],
#         [ 1,  1, -1,  1]])

# %%
Av = np.dot(A, V)
Av
# Out:
# matrix([[ 1,  2, -1,  5],
#         [ 4,  2, -4, -4]])

# %%
def vectorfy(mtrx, clmn):
    return np.array(mtrx[:, clmn]).reshape(-1)

# %%
vectorfy(V, 0)
# Out:
# array([3, 1])

# %%
vectorfy(V, 0) == v
# Out:
# array([ True,  True])

# %%
plot_vectors([vectorfy(V, 0)])

# %%
plot_vectors([vectorfy(V, 0), vectorfy(V, 1), vectorfy(V, 2), vectorfy(V, 3), vectorfy(Av, 0), vectorfy(Av, 1), vectorfy(Av, 2), vectorfy(Av, 3)],
            ['lightblue', 'lightgreen', 'lightgray', 'orange', 'blue', 'green', 'gray', 'red'])
plt.xlim(-4, 6)
_ = plt.ylim(-5, 5)

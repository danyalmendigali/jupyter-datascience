# %%
x = 25
x
# Out:
# 25

# %%
type(x)
# Out:
# int

# %%
y = 3
py_sum = x + y
py_sum
# Out:
# 28

# %%
type(py_sum)
# Out:
# int

# %%
x_float = 25.0
float_sum = x_float + y
float_sum
# Out:
# 28.0

# %%
type(float_sum)
# Out:
# float

# %%
import torch

# %%
x_pt = torch.tensor(25)
x_pt
# Out:
# tensor(25)

# %%
x_pt.shape
# Out:
# torch.Size([])

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(25, dtype=tf.int16)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=25>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(3, dtype=tf.int16)
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=28>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=28>

# %%
tf_sum.numpy()
# Out:
# np.int16(28)

# %%
type(tf_sum.numpy())
# Out:
# numpy.int16

# %%
tf_float = tg.Veriable(25, dtype=th.ffloat16)
tf.
